# %%
# exportar con imágenes y sin código: jupyter nbconvert --to HTML --no-input PSU.ipynb
# HTML -> 'Save as PDF' (Chrome mantiene coherencia con los hipervínculos)
"""
La gran mayoría (sino todas) las fuentes que se venden para la raspberry pi son del tipo switching
- Una fuente de alimentación lineal a transformador, utiliza un reductor de tensión (el transformador) y se rectifica y filtra la salida de éste. En algunos casos se la ajusta mediante reguladores lineales. La regulación de tensión y/o corriente se logra mediante la disipación de calor con lo cual la eficiencia es baja.
- Una fuente switching regula la corriente y tensión de salida mediante la conmutación de componentes de almacenaje, como inductores o capacitores, y la eficiencia es mucho mayor
""";

# %% [markdown]
# <div style="text-align: center">
#     <h1>Raspberry Pi - Fuentes de alimentación</h1>
# </div>

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Probattery FASW-053100F</h2>
# </div>
# <table style="cellpadding: 0px">
#     <tr>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="./images/Probattery-IQC.jpg" width=250px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/FASW-053100F.jpg" width=250px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <!--<td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/Probattery_Copper.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>-->
#     </tr>
# </table>
# <table style="cellpadding: 0px">
#     <tr>
#         <td style="padding: 0px">
#             <span>Características</span>
#             <ul style="word-wrap: break-word; width: 500px">
#                 <li>5V 3100mA</li>
#                 <li>Certificada por IQC</li>
#                 <li>Cables de 20AWG (el mínimo recomendado). A menor grosor del cable,
#                     mayor resistencia, y mayor caída de tensión cuando el consumo se incrementa.</li>
#                 <li>Conector micro-USB</li>
#                 <li>Cabe aclarar que Probattery es la marca, pero el diseño circula en china, y cada importador le asigna su marca. Por ejemplo la Pronext FU-5V2500 tiene el PCB idéntico.</li>
#             </ul>
#         </td>
#         <td colspan="2" style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/FASW-053100F_1700mA_4700mV_HR.png" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">Ripple @1.70A</figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
from IPython.core.display import HTML

img = Image.open('./images/Probattery_Copper.jpg')
img = img.rotate(90, expand=1)
fig, ax = plt.subplots()
fig.set_figheight(600)
ax.set_axis_off()
ax.annotate('', xy=(1330,200), xytext=(1700,200), arrowprops=dict(arrowstyle="|-|",color="yellow"))
ax.annotate('Creepage: ~8mm', xy=(1300,100), color='yellow')
HTML("""
<style>
     .output_png {
        display: table-cell;
        text-align: center;
        vertical-align: middle;
    }
</style>
""")
ax.imshow(img);

# %% [markdown]
# <!--<hr>
# <div style="text-align: center">
#     <h2>Pronext FU-5V2500</h2>
# </div>
# <table style="cellpadding: 0px">
#     <tr>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/Pronext-IQC.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/FU-5V2500.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/RE.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>
# <table style="cellpadding: 0px">
#     <tr>
#         <td style="padding: 0px">
#             <span>Características</span>
#             <ul style="word-wrap: break-word; width: 200px">
#                 <li>5V 2500mA (la corriente mínima recomendada)</li>
#                 <li>Certificada por IQC</li>
#                 <li>Cables de 20AWG</li>
#                 <li>Conector micro-USB (las hay con jack USB; ver el caso del cargador Motorola)</li>
#             </ul>
#         </td>
#         <td colspan="2" style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/FU-5V2500_1680mA_4640mV_HR.png" min-width=800px style="background: white"/>
#                 <figcaption style="text-align: center">Ripple @1.68A</figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>
# -->

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Cargador Motorola "TurboPower" Modelo SC-56</h2>
# </div>
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <ul>
#                 <li>5V 3000mA</li>
#                 <li>Certificado por TÜV</li>
#             </ul>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/SC-56_01.jpg" width=300px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/SC-56_04.jpg" width=300px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Fuentes DC/DC step-down</h2>
# </div>
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/AC-DC.jpg" width=800px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <p style="word-wrap: break-word; width: 300px">¿Qué tienen en común las fuentes de la imagen? Están normalizadas
#              - algunas incluso a niveles mucho más <strong>rigurosos</strong> que las fuentes de 5V que se consiguen en el país -.
#             Suelen acumularse de productos que ya no se usan. Y &nbsp;<strong>todas</strong>&nbsp;
#             son compatibles con los conversores DC/DC mencionados</p>
#         </td>
#     </tr>
# </table>
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: right">
#                 <img src="images/DC-DC_01.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center">
#                     Convertidor step-down (buck) a 5V 5A "XY-3606T"
#                 </figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <figure style="text-align: right">
#                 <img src="images/HW-298.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center">
#                     Convertidor step-down 5V 3A "HW-298"<br/>
#                     Nota: el identificador del chip fue borrado con láser. Pero hay un módulo muy similar, el CKCY-U1A,<br/>
#                     cuyo chip es el IP6505 (que definitivamente no es el mismo chip que el del HW-298)
#                 </figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#         </td>
#     </tr>
# </table>
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: right">
#                 <img src="images/UPS-12V.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <p style="word-wrap: break-word; width: 300px">Una de las mejores ventajas, es la posibilidad de implementar un UPS de 12V,
#             que en caso de una falla del suministro eléctrico, administrará la tensión de la batería de respaldo.</p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Menciones de Honor</h2>
# </div>
# <table style="cellpadding: 0px">
#     <tr>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/DPP25-5_RS-Components.webp" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <strong>TDK-Lambda DPP25-5</strong>
#             <ul style="word-wrap: break-word; width: 300px">
#                 <li><strong>MTBF</strong> (Tiempo medio entre fallos) > 288000 horas</li>
#                 <li>sólo para soñar... (?)</li>
#                 <li>Más info en <a href="https://product.tdk.com/en/search/power/switching-power/ac-dc-converter/info?part_no=DPP25-5">TDK DPP25-5</a></li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="padding: 0px">
#             <figure style="text-align: center">
#                 <img src="images/Official-PSU.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td style="padding: 0px">
#             <span>Fuente Oficial (1, 2 y 3)</span>
#             <ul style="word-wrap: break-word; width: 300px">
#                 <li><strong>MTBF</strong> 50000 horas</li>
#                 <li>Más info en <a href="https://www.raspberrypi.com/products/raspberry-pi-universal-power-supply/">R-Pi PSU</a></li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <hr>
#
# ## Cables
#
# - USB-2.0 micro-B
#   - El estándar fue pensado para 5v@100mA de alimentación inicial y 5v@500mA luego del "negociado". La mayoría de cargadores ignoran estos límites, pero los cables son los mismos
#   - Los conectores USB-2.0 micro-B son fabricados, en general, para soportar 1.8A max en los pines de alimentación, con una resistencia de contacto de 30mΩ max
#   - Como se verá más adelante, casi todas las fuentes fallaron utilizando un cable estandarizado de este tipo y fue necesario alimentar la Raspberry por el pin de 5V
#
# &nbsp;
#
# - USB-C
#   - La corriente mínima tras negociado es de 900mA.
#   - Los cables de USB-A 2.0 a USB-C por norma deben admitir 3A de corriente.
#   - La máxima caída de tensión para la línea VBus, incluyendo contactos es de 500mV; para GND es 250mV.
#   - Los conectores USB-C admiten entre 3A y 5A, con una resistencia de contacto de 30mΩ (según algunos fabricantes)
#
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/micro-usb.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <p style="word-wrap: break-word; width: 400px">
#                 El cable color negro es original, de un celular Samsung, pero no superó la prueba de demanda.
#                 El espesor de los conductores no son adecuados y además influye la longitud del cable.<br/>
#                 Esto es esperable, dado que el estándar exige un calibre para los conductores de alimentación de un mínimo de 28 AWG, y por supuesto, los fabricantes usarán el mínimo.<br/>
#                 El azul transparente (genérico) es más corto y por tanto tendrá menor caída de tensión.<br/>
#                 (Suelen venir con Arduínos clones)<br/>
#                 <br/>
#                 Un buen cable USB 2.0 deberá estar mallado, y esta malla formará parte de la conexión eléctrica entre las vainas metálicas de los plugs extremos.
#                 Tanto la Raspberry Pi como las fuentes de alimentación testeadas conectan la malla a GND, aprovechando la malla, y reduciendo la caída de tensión en la línea GND<br/>
#                 Sin embargo el cable azul transparente mostrado no tiene esta conexión hecha.
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/DEBO_MICROUSB_2_001.png" width=300px style="background: white"/>
#                 <figcaption style="text-align: center">USB micro-B breakout board</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/usb-male-to-dip-breakout-board.webp" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">USB-A breakout board</figcaption>
#             </figure>
#         </td>
#         <td>
#             <p style="word-wrap: break-word; width: 300px">
#                 Ante problemas de caídas de tensión en cables, podemos armar uno, ya sea reciclando los conectores de otros cables o comprando unos. Se podría adaptar un cable USB-C a micro-B con algún adaptador, pero no lo he probado.<br/>
#                 El cable armado deberá tener un calibre mínimo de 20 o 18 AWG<br/>
#                 <br/>
#                 También se puede obviar el conector micro-USB, y alimentar directamente al pin 5V de la Raspberry,
#                 pero al hacerlo se omite el fusible reseteable que está entre el socket micro-USB de la R-Pi y el rail de 5V
#             </p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Armado de un cable
#
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB01.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">Desarmamos un cable fuera de norma</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB02.jpg" width=300px style="background: white"/>
#                 <figcaption style="text-align: center">Usamos manguitos de Heat Shrink</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB03.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB04.jpg" width=300px style="background: white"/>
#                 <figcaption style="text-align: center">Heat Shrink 8.0/4.0 para el exterior sobre uno de 7.0/3.5</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB05.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB06.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB07.jpg" width=300px style="background: white"/>
#                 <figcaption style="text-align: center">Aplicamos silicona y moldeamos con cinta de papel</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB08.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/USBmicroB09.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">Usamos uno de 13.0/6.5 sobre uno de 9.0/4.5</figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>
#
# El cable armado tiene una resistencia de 104.3mΩ  <br/>
# La medición de estas resistencias, al ser bajas, se realizó haciendo pasar una corriente mayor a 1.5A, midiendo la caída de tensión para luego usar la ley de Ohm

# %% [markdown]
# <hr>
#
# ## Medicion de ripple y prueba de stress:
#
# ### Raspberry Pi 3b+
#
# - Resistencias de potencia de 1.7Ω  y 2.7Ω para la prueba de ripple.
# - `stress-ng -c 4 -l 95 -t 30` para la prueba de stress. Se indica min/max de un multímetro en modo captura.
# - Display 7" HDMI alimentado por puerto USB como demanda adicional de corriente.
# - La columna "USB" indica que se alimenta la Raspberry por USB, ya sea por el cable propio de la fuente, o el color azul mencionado, de 268mΩ (resistencia del conductor rojo)
#   - ⛔ Indica que el cable USB ya está incorporado en la fuente y esta prueba seria inválida
# - La columna "+5V" indica alimentación por medio del correspondiente pin mediante un cable armado
# - ➡️ indica que no es necesaria esta prueba, al pasar la prueba por USB
#
# <table style="text-align:center; font-size:x-small">
#     <tr>
#         <th rowspan=2>Fuente</th><th rowspan=2>Imax<br/>(A)</th><th colspan=2>Ripple (mVpp)</th><th colspan=2>Ripple (mVrms)</th>
#         <!--<th rowspan=2>SWF<br/>(KHz)</th>-->
#         <th colspan=6><span style="font-family:monospace;color:orange;">stress-ng</span>&nbsp; 95% &nbsp; ~4.97W</th>
#         <th colspan=6><span style="font-family:monospace;color:orange;">stress-ng</span>&nbsp; 95% + HDMI display &nbsp; ~8.34W</th>
#         <!--<th rowspan=2>%Ef</th>-->
#         <!--<th rowspan=2>link</th>-->
#         <th rowspan=2>Precio @ML<br/>(19/09/23)</th>
#     </tr>
#     <tr>
#         <td>A</td><td>B</td><td>A</td><td>B</td>
#         <td>USB</td><td>Vmin</td><td>Vmax</td><td>+5V pin</td><td>Vmin</td><td>Vmax</td><td>USB</td><td>Vmin</td><td>Vmax</td><td>+5V pin</td><td>Vmin</td><td>Vmax</td>
#     </tr>
#     <tr><td>Pronext FU-5V2500          </td><td>2.5</td>
#         <td>216 @1.70A</td><td>204 @2.42A</td><td>62.4 @1.70A</td><td>61.3 @2.42A</td>
#         <!--<td>34.0</td>-->
#         <td>✅</td><td>4.865</td><td>5.124</td><td>⛔</td><td>-</td><td>-</td>
#         <td>✅</td><td>4.751</td><td>4.961</td><td>⛔</td><td>-</td><td>-</td>
#         <!--<td>78..88</td>-->
#         <!--<td><a href="">🔗</a></td>-->
#         <td>-</td></tr>
#     <tr><td>Probattery FASW-053100F    </td><td>3.1</td>
#         <td>25.5 @1.70A</td><td>26.1 @2.49A</td><td>5.39 @1.70A</td><td>5.13 @2.49A</td>
#         <!--<td>64.5</td>-->
#         <td>✅</td><td>4.957</td><td>5.173</td><td>⛔</td><td>-</td><td>-</td>
#         <td>✅</td><td>4.793</td><td>5.008</td><td>⛔</td><td>-</td><td>-</td>
#         <!--<td>78..88</td>-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-735964658-fuente-homologada-25a-microusb-raspberry-pi-filtro-emakers-_JM">🔗</a></td>-->
#         <td>$8.588</td></tr>
#     <tr><td>Motorola "TurboPower" SC-56</td><td>3.0</td>
#         <td>39.2 @1.60A</td><td>45.0 @2.32A</td><td>10.4 @1.60A</td><td>12.2 @2.32A</td>
#         <!--<td>72</td>-->
#         <td>✅</td><td>4.731</td><td>5.031</td><td>➡️</td><td>-</td><td>-</td>
#         <td>❌</td><td><span style="color:red">4.492</span></td><td>4.868</td><td>✅</td><td>4.888</td><td>5.093</td>
#         <!--%-->
#         <td colspan=1>Original</td></tr>
#     <tr><td>DC/DC 5V5A "XY-3606T"      </td><td>5.0</td>
#         <td>88.8 @1.62A</td><td>86.0 @2.33A</td><td>10 @1.62A</td><td>10 @2.33A</td>
#         <!--<td></td>-->
#         <td>✅</td><td>4.731</td><td>5.069</td><td>➡️</td><td>-</td><td>-</td>
#         <td>❌</td><td><span style="color:red">4.485</span></td><td>4.817</td><td>✅</td><td>4.940</td><td>5.072</td>
#         <!--%-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-823543253-modulo-power-dc-dc-step-down-24v12v-a-5v-5a-4-usb-conversor-_JM">🔗</a></td>-->
#         <td>$9.693</td></tr>
#     <tr><td>DC/DC 5V3A "XY-3606"       </td><td>3.0</td>
#         <td>151 @1.56A</td><td>131 @2.25A</td><td>36.2 @1.56A</td><td>30.9 @2.25A</td>
#         <!--<td>120</td>-->
#         <td>❌</td><td><span style="color:red">4.623</span></td><td>4.970</td><td>✅</td><td>4.874</td><td>5.041</td>
#         <td>❌</td><td><span style="color:red">4.581</span></td><td>4.713</td><td>✅</td><td>4.772</td><td>4.962</td>
#         <!--%-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-681090787-step-down-usb-xy-3606-9-36v-a-5v-3a-jack-dc-itytarg-_JM">🔗</a></td>-->
#         <td>$6.871</td></tr>
#     <tr><td>DC/DC 5V "KIS-3R33S"       </td><td>3.0</td>
#         <td>70.4 @1.54A</td><td>64.0 @2.21A</td><td>19.3 @1.54A</td><td>16.5 @2.21A</td>
#         <!--<td>330</td>-->
#         <td>❌</td><td><span style="color:red">4.568</span></td><td>4.939</td><td>✅</td><td>4.697</td><td>4.990</td>
#         <td>❌</td><td><span style="color:red">H</span></td><td><span style="color:red">H</span></td><td>❌</td><td><span style="color:red">4.552</span></td><td>4.850</td>
#         <!--%-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-677165816-step-down-kis3r33s-usb-dc-7v-24-v-a-5v-3a-itytarg-_JM">🔗</a></td>-->
#         <td>$3.875</td></tr>
#     <tr><td>DC/DC 5V "HW-298"          </td><td>3.0</td>
#         <td>188 @1.61A</td><td>163 @2.33A</td><td>55 @1.61A</td><td>46.5 @2.33A</td>
#         <!--<td>108</td>-->
#         <td>✅</td><td>4.757</td><td>5.050</td><td>➡️</td><td>-</td><td>-</td>
#         <td>❌</td><td><span style="color:red">4.546</span></td><td>4.849</td><td>✅</td><td>4.885</td><td>5.052</td>
#         <!--<td>90..97</td>-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-1160569902-modulo-regulador-voltaje-dc-dc-step-down-usb-8-32v-a-5v-3a-_JM">🔗</a></td>-->
#         <td>$2.999</td></tr>
#     <tr><td>DC/DC 5V MP2314            </td><td>2.2</td>
#         <td>127 @1.60A</td><td>180 @2.27A</td><td>13.8 @1.60A</td><td>17.8 @2.27A</td>
#         <!--<td></td>-->
#         <td>✅</td><td><span style="color:orange">4.674</span></td><td>4.967</td><td>➡️</td><td>-</td><td>-</td>
#         <td>❌</td><td><span style="color:red">4.399</span></td><td>4.761</td><td>✅</td><td>4.882</td><td>5.009</td>
#         <!--%-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-861215214-modulo-de-carga-usb-entrada-6-a-24v-salida-5v-3a-15watts-_JM">🔗</a></td>-->
#         <td>$2.659</td></tr>
#     <tr><td>DC/DC MP1584 @5.18V        </td><td>2.2</td>
#         <td>17 @1.59A</td><td>1400 @2.25A</td><td>4.2 @1.59A</td><td>433 @2.25A</td>
#         <!--<td>95</td>-->
#         <td>❌</td><td><span style="color:red">4.621</span></td><td>5.027</td><td>✅</td><td>4.789</td><td>5.082</td>
#         <td>❌</td><td><span style="color:red">4.582</span></td><td>4.749</td><td>✅</td><td>4.718</td><td>4.913</td>
#         <!--<td>82..91</td>-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-822447925-modulo-fuente-dc-dc-step-down-08-20v-3-amper-mp1584-_JM">🔗</a></td>-->
#         <td>$2.179</td></tr>
#     <tr><td>DC/DC LM2596HVS @5.18V     </td><td>3.0</td>
#         <td>630 @1.54A</td><td>532 @2.21A</td><td>183 @1.54A</td><td>154 @2.21A</td>
#         <!--<td>52</td>-->
#         <td>❌</td><td><span style="color:red">4.587</span></td><td>4.998</td><td>✅</td><td>4.837</td><td>5.081</td>
#         <td>❌</td><td><span style="color:red">4.519</span></td><td><span style="color:orange">4.685</span></td><td>✅</td><td>4.742</td><td>4.913</td>
#         <!--<td>..94</td>-->
#         <!--<td><a href="https://articulo.mercadolibre.com.ar/MLA-677246804-lm2596-fuente-step-down-dc-dc-123-30v-3a-arduino-orig-gtia-_JM">🔗</a></td>-->
#         <td>$1.450</td></tr>
#     <tr><td>Fuente 5V 4A               </td><td>4.0</td>
#         <td>45.7 @1.62A</td><td>52.8 @2.34A</td><td>4.37 @1.62A</td><td>4.56 @2.34A</td>
#         <!--<td>53.5</td>-->
#         <td colspan=12>Ver prueba en Raspberry Pi 4</td>
#         <!--<td>%</td>-->
#         <!--<td><a href="">🔗</a></td>-->
#         <td>$9.900</td></tr>
#     <tr><td></td></tr>
#     <tr><td>DC/DC 5V 3A "HW-298"</td><td colspan=5>Repetimos, utilizando el cable armado en lugar del genérico</td>
#         <td>✅</td><td>4.918</td><td>5.065</td><td>➡️</td><td>-</td><td>-</td>
#         <td>✅</td><td>4.749</td><td>4.949</td><td>➡️</td><td>-</td><td>-</td></tr>
#     <!--<tr><td>ATX PSU[^1]                </td><td>88.3 @1.55A</td><td>97.0 @2.22A</td><td>6.0 @1.55A</td><td>10  @2.22A</td>
#         <td>❌</td><td>✅</td><td>-</td><td>-</td></tr>-->
# </table>
#
# - H: Hiccup mode
#
# Las pruebas realizadas son sencillas. Sirven como comparación entre una o otra fuente. El ripple real, la eficiencia, etc. quedarán pendientes.

# %% [markdown]
# <figure style="text-align: center">
#     <img src="images/PB_HDMI_75_95.png" width="800px" style="background: white"/>
#     <figcaption style="text-align: center">Ejemplo de variación de tensión medida en el pin +5V. Fuente Probattery con distintas demandas</figcaption>
# </figure>

# %% [markdown]
# ### Raspberry Pi 4
#
# - Display 7" HDMI alimentado por la Raspberry
# - Raspberry Pi alimentada por USB-C (cable original del Motorola TurboPower, 198mΩ entre pin 1 y pin A1)
# - Raspbian 11 Desktop; Case Argon ONE V2; WiFi+BT on
# - `stress-ng -c 4 -l 95 -t 30`
#
# <table style="text-align:center">
#     <tr>
#         <th rowspan=2>Fuente</th>
#         <th colspan=3><span style="font-family:monospace;color:orange;">stress-ng</span>&nbsp; 95% + HDMI display</th>
#         <th colspan=3><span style="font-family:monospace;color:orange;">stress-ng</span>&nbsp; 95% + HDMI display + Hub*</th>
#     </tr>
#     <tr>
#         <td>USB-C</td><td>Vmin</td><td>Vmax</td><td>USB-C</td><td>Vmin</td><td>Vmax</td>
#     </tr>
#     <tr><td>Motorola "TurboPower" SC-56</td>
#         <td>✅</td><td>4.896</td><td>5.067</td><td>✅</td><td>4.894</td><td>5.070</td></tr>
#     <tr><td>DC/DC 5V 5A "XY-3606T"     </td>
#         <td>✅</td><td>4.800</td><td>4.966</td><td>✅</td><td>4.755</td><td>4.950</td></tr>
#     <tr><td>DC/DC 5V 3A "HW-298"       </td>
#         <td>✅</td><td>4.718</td><td>4.962</td><td>✅‡</td><td>4.733</td><td>4.953</td></tr>
#     <tr><td>DC/DC 5V 2A MP2314         </td>
#         <td>✅</td><td>4.733</td><td>4.948</td><td>✅§</td><td>4.708</td><td>4.938</td></tr>
#     <tr><td>DC/DC MP1584 @5.18V        </td>
#         <td>✅</td><td>4.718</span></td><td>4.913</td><td>✅</td><td><span style="color:orange">4.689</span></td><td>4.894</td></tr>
#     <tr><td>DC/DC LM2596HVS @5.18V     </td>
#         <td>✅</td><td><span style="color:orange">4.689</span></td><td>4.913</span></td>
#         <td>✅</td><td><span style="color:orange">4.667</span></td><td>4.872</span></td></tr>
#     <tr><td>Fuente 5V 4A               </td>
#         <td>✅</td><td>4.757</td><td>4.957</span></td>
#         <td>✅</td><td>4.719</td><td>4.954</span></td></tr>
#     <!--<tr><td>ATX PSU[^1]                </td><td>88.3 @1.55A</td><td>97.0 @2.22A</td><td>6.0 @1.55A</td><td>10  @2.22A</td>
#         <td>❌</td><td>✅</td><td>-</td><td>-</td></tr>-->
# </table>
#
# - *El Hub incluye un módulo FT2232H, adaptador USB a PS2, y una capturadora USBTV007
#
# <table style="text-align:center">
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/HW-298_Temp.jpg" width="400px" style="background: white"/>
#                 <figcaption style="text-align: center">‡: Termográfica durante la prueba</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/MP2314_Temp.jpg" width="400px" style="background: white"/>
#                 <figcaption style="text-align: center">§: Termográfica durante la prueba</figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Estados del LED rojo
#
# - Continuo: alimentación adecuada
# - Apagado: Brownout, tensión insuficiente; menor o igual a 4.63V
#   - Este detector es rudimentario, y puede activarse con tensiones <= 4.7V

# %%
"""
Analog Discovery 2
- Hyst: 0V
- HoldOff 20us
- Time Base: 50us
- Ch1 -4.36V 100mV/div
- Peak2Peak Value + Mean
- AC RMS Value + Mean
- https://lygte-info.dk/review/USBpower%20Xtar%20WallAdapter%202.1A%20UK.html --> Probattery
""";

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Componentes críticos</h2>
# </div>
# <figure style="text-align: center">
#     <img src="images/FU-5V2500-schematic.png" width=1000px style="background: white"/>
#     <figcaption style="text-align: center">Fuente Pronext FU-5V2500</figcaption>
# </figure>

# %% [markdown]
# En el circuito de arriba hay dos componentes críticos: C9 y U1.
#
# ### Capacitor-Y
#
# C9 es un capacitor clase-Y, puesto como retorno del ruido de alta frecuencia (switching) de modo común, para cumplir con normas de EMI. Son de clase-Y porque están conectados directamente a la tensión de línea, y deben soportar sobretensiones, y en caso de fallar, deben quedar abiertos, y no en cortocircuito. Por tal motivo, <strong>deben ser buenos, y estar certificados</strong>
#
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/Type-Y_01.jpg" width=250px style="background: white"/>
#                 <figcaption style="text-align: center">Capacitor clase-Y (fuente Pronext)</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/Type-Y_02.jpg" width=250px style="background: white"/>
#                 <figcaption style="text-align: center">Ejemplo de capacitor clase-Y (fuente Delta TADP-25KB)</figcaption>
#             </figure>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Marcas de aprovación:
#             <ul>
#                 <li><img src="images/CCC.webp" width=40px style="background: white"/>&nbsp;<span>CCC mark <br/> (China Compulsory Certification, supongo, porque apenas se ve)</span></li>
#                 <li><img src="images/ul_cruus.gif" width=60px style="background: white"/>&nbsp;<span>Recognized Component Mark for Canada <br/> and the United States</span></li>
#                 <li><img src="images/vde_drei.gif" width=40px style="background: white"/>&nbsp;<span>VDE Mark <br/> (Verband Deutscher Elektrotechniker)</span></li>
#             <ul>
#         </td>
#         <td>
#             <ul>
#                 <li>S: SEMKO (Svenska elektriska Materielkontrollanstalten)</li>
#                 <li>N: NEMKO (Norges Elektriske Materiellkontroll)</li>
#                 <li>D: DEMKO</li>
#                 <li>CSA</li>
#                 <li>FI: FIMKO</li>
#                 <li>IMQ: Istituto Italiano del Marchio di Qualità</li>
#                 <li>Recognized Component Mark</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Un efecto secundario de este capacitor, es propiciar una fuga de AC de 50hz, cuyo valor de tensión dependerá de los valores del divisor de tensión capacitivo formado entre este capacitor y el parasítico de los bobinados primario y secundario.
# Esta tensión de fuga es de 80V rms en el caso de la fuente Pronext, que por normas internacionales, no debería superar los 0.25mA en caso de una conexión a tierra por intervención de una persona.
#
# Esta tensión estará presente siempre que se use una fuente switching, con la Raspberry Pi flotante, es decir, con GND sin conexión a tierra; y bajo ciertas condiciones, puede ocasionar fallas, como resetearse al tocar el pin RUN.
# Este problema se elimina aterrizando la R-Pi, con una conexión directa a tierra o a través de un capacitor de 1uF. Esta conexión también solucionará problemas de ESD, que también pueden resetear la R-Pi o peor.
#
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/R-Pi_Floating-vs-Grounded.jpg" width=800px style="background: white"/>
#                 <figcaption style="text-align: center">Tensión de fuga de 50hz presente en los pines de la Raspberry, antes y después de aterrizarla</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/RUN-Reset.png" width=800px style="background: white"/>
#                 <figcaption style="text-align: center">Reset ocasionado al tocar el pin RUN en una Raspberry no aterrizada</figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Transformador Switching
#
# El otro componente crítico es U1, el transformador switching (flyback): Una falla de aislación entre bobinados implica un peligro directo
#
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/Samsung_Flyback.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center">
#                     Transformador flyback de una fuente Samsung certificada<br/>
#                     Se puede observar el aislamiento triple del secundario (TIW: Triple Insulated Wire) sumada a la cinta<br/>
#                     La separación es de aprox 0.2mm
#                 </figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/PRO21_Flyback.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center">
#                     Transformador flyback de una fuente PRO21<br/>
#                     La aislación son 3 capas de cinta<br/>
#                     La separación es de aprox 0.1mm
#                 </figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Otros componentes
#
# ### Capacitores electrolíticos
#
# <table style="cellpadding: 0px">
#     <tr>
#         <td>
#             <p style="word-wrap: break-word; width: 400px">
#                 La mayoría de los encontrados en estas fuentes, son de electrolito líquido. Los foils de aluminio (ánodo y cátodo) son separados por un papel impregnado en electrolito líquido. Al calentarse por encima de la temperatura máxima para la cual están fabricados, el electrolito comienza a ganar presión de vapor, y el armazón del capacitor se expande, liberándose parte del electrolito tanto por el sello de goma inferior, como por las ranuras de seguridad marcadas en la parte superior. Esta pérdida de electrolito aumenta el ESR, lo que aumenta la temperatura bajo corrientes de ripple, lo que continúa con este efecto bola de nieve, hasta que el capacitor pierde por completo su función.<br/>
#                 En un recinto cerrado como el de varias fuentes citadas, la eficiencia de las mismas determinará la temperatura de sus componentes: una fuente con una eficiencia del 88%, con una potencia de salida de 12.5W, disipará 1.5W en forma de calor. Si la eficiencia es muy baja, este calor tendrá efectos nocivos en los capacitores electrolíticos. La situación empeora si la zona de trabajo está a temperaturas considerables, como ser el interior de un gabinete estanco junto a elementos de potencia.
#             </p>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/capacitor-fail.jpg" width=500px style="background: white"/>
#                 <figcaption style="text-align: center">Foto cortesía de @Norberto</figcaption>
#             </figure>
#         </td>
#     </tr>
#     <tr><td colspan=2>
#         <p>Pueden encontrarse capacitores situados cerca de componentes con tendencia a calentarse. Esto no es preocupante; habrá transmisión de calor por convección y radiación, pero dentro de los parámetros de seguridad. Diferente sería el caso grave de un capacitor en contacto directo con un disipador metálico, donde se suma la transmisión por conducción (ver fuente Belsic). También puede ocurrir que capacitores baratos marcados para 105°C, realmente no estén hechos para esa temperatura.</p>
#         <p>Regla: supongamos que un capacitor para temperaturas de -55°C a 105°C tiene una vida útil de 2000h@85°C. Por cada incremento en 10°C la vida útil se reduce a la mitad (y se duplica por cada disminución en temperatura). Esto significa que a 105°C, su vida útil será aprox &nbsp;$2000/2^{\frac{105-85}{10}}=500$ horas.</p>
#     </td></tr>
# </table>

# %%
efficiency = 88
powerOut = 5*2.5
heatLossW = (100-efficiency)/100*powerOut
"""
Una fuente bien diseñada (y cuidada) podría durar décadas sin daños en sus capacitores.
https://www.analog.com/en/technical-articles/ensure-long-lifetimes-from-electrolytic-capacitors-a-case-study-in-led-light-bulbs.html

<h3>Categorías de Contaminación</h3>

<ul>
    <li><i>Pollution degree 1</i>: No hay contaminación o solo se produce contaminación seca y no conductora.
        La contaminación no tiene ningún efecto. (Placas sometidas a <i>conformal coating</i>)</li>
    <li><i>Pollution degree 2</i>: Normalmente sólo se produce contaminación no conductiva.
        Es de esperar una conductividad temporal causada por la condensación. (En esta categoría caen las fuentes de uso hogareño)</li>
    <li><i>Pollution degree 3</i>: Se produce contaminación conductiva o contaminación seca no conductora que se vuelve conductora debido a la condensación.
        Se encuentra en entornos industriales o en obras de construcción (ambientes hostiles).</li>
</ul>
""";

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>MODELOS DE CERTIFICACION – TIPO, MARCA y LOTE</h2>
# </div>
# <figure style="text-align: center">
#     <img src="images/certificacion.jpeg" width=500px style="background: white"/>
#     <figcaption style="text-align: center"></figcaption>
# </figure>
# <figure style="text-align: center">
#     <img src="images/toshiba-delta.jpg" width=500px style="background: white"/>
#     <figcaption style="text-align: center"></figcaption>
# </figure>

# %% [markdown]
# <ul>
#     <li>Modelo ISO/CASCO Nº4: Ensayo de Tipo seguido por una supervisión posterior a través del ensayo de auditoria de muestras del comercio y de la fábrica.</li>
#     <li>Modelo ISO/CASCO Nº5: Marca de Conformidad Ensayo de tipo y evaluación del control de calidad en la planta seguido por una supervisión que considera la auditoria del control de calidad en la fábrica ensayos de muestras tomadas en la fábrica y en el comercio.</li>
#     <li>Modelo ISO/CASCO Nº7: Servicio que certifica mediante ensayos técnicos de laboratorio y el análisis de los resultados obtenidos, la conformidad de un lote específico de productos de acuerdo con lo establecido en las normas y reglamentos .El ensayo por lotes es un modelo según el cual se extraen muestras de un lote del producto y se someten a ensayo; en base al resultado del ensayo se emite un veredicto sobre la conformidad del lote con la norma.</li>
# </ul>

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <p>Los Organismos de Certificacion Acreditados ante OAA son:</p>
#             <ul>
#                 <li>Bureau Veritas</li>
#                 <li>Instituto del Gas Argentino</li>
#                 <li>Intertek</li>
#                 <li>INTI</li>
#                 <li>IQC</li>
#                 <li>IRAM</li>
#                 <li>Lenor</li>
#                 <li>Net Connection International</li>
#                 <li>Qetkra</li>
#                 <li>TÜV Rheinland</li>
#                 <li>UL</li>
#             </ul>
#         </td>
#         <td>
#             <p>Los laboratorios acreditados ante el OAA son:</p>
#             <ul>
#                 <li>CES – Compliance Engineering Services S.A.</li>
#                 <li>IADEV</li>
#                 <li>Ladet</li>
#                 <li>Lamyen</li>
#                 <li>LEC – (Laboratorio de Ensayos y Certificaciones) Universidad Nacional de Río Cuarto</li>
#                 <li>Lenor</li>
#                 <li>Shitsuke</li>
#             </ul>
#         </td>
#     <tr>
# <table>
# <p>Más información: <a href="https://www.fonse.org.ar/evolucion-de-la-certificacion-de-seguridad-electrica-en-el-campo-regulatorio/">Evolución de la certificación de Seguridad Eléctrica en el campo regulatorio</a></p>

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/pronext-tuv.jpg" width=800px style="background: white"/>
#                 <figcaption style="text-align: center">Fuente certificada por TÜV</figcaption>
#             </figure>
#         </td>
#         <td>
#             <strong>Algunos indicadores de seguridad/calidad:</strong>
#             <ul style="word-wrap: break-word; width: 350px">
#                 <li>A: Fusible</li>
#                 <li>B: NTC, limitador de corriente de irrupción (inrush o switch-on)</li>
#                 <li>C: Filtro de modo común</li>
#                 <li>D: "Silastic", silicona neutra. Vibraciones pueden debilitar las patas de los componentes hasta quebrarlas.</li>
#                 <li>E: Filtro de modo diferencial/normal. Es un capacitor clase-X que debe estar certificado</li>
#                 <li>F: Filtro de modo común adicional</li>
#                 <li>G: Capacitor de 105°C de filtrado de AC (posterior al puente de rectificadores). Nichicon, Nippon Chemi-Con, Panasonic, Illinois Capacitor, Rubycon son buenas marcas</li>
#             </ul>
#             <span>También se pueden encontrar:</span>
#             <ul>
#                 <li>Ranuras (fresadas) para incrementar el <a href="https://blog.samtec.com/post/creepage-and-clearance-and-why-we-care-about-it/">creepage</a></li>
#                 <li>Barreras de plástico de separación, que incrementan el <a href="https://blog.samtec.com/post/creepage-and-clearance-and-why-we-care-about-it/">clearance y creepage</a></li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/compare.jpg" width=800px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#         <td>
#             <p style="word-wrap: break-word; width: 350px"><strong>En general: a mayor potencia, mayor tamaño del componente</strong>
#                 - y en este caso, comparando fuentes de 5V, a mayor corriente, mayor tamaño (y peso).<br/>
#             Comparación entre la fuente "PRO21", <i>supuestamente</i> certificada por IQC. de <strong>2100mA</strong>,
#             y la Pronext, certificada por TÜV, de unos humildes 1500mA</p>
#             <ul style="word-wrap: break-word; width: 350px">
#                 <li>A: Fusibles: posiblemente de vidrio en la fuente Pronext; en el caso de la PRO21... desconfío.</li>
#                 <li>B: Capacitor Clase-X de filtrado de modo diferencial, ausente en la PRO21</li>
#                 <li>C: Silicona de contención, ausente en la PRO21</li>
#                 <li>D: Capacitor Clase-Y, el de la PRO21 parece estar certificado</li>
#                 <li>E: Comparen los tamaños de los transformadores switching...</li>
#                 <li>F: Diodo de salida. El de la Pronext se ve robusto. En el caso de la PRO21, es de montaje superficial, y no tiene pinta de ser de 2A</li>
#             </ul>
#             <p>Por supuesto que la PRO21 falló miserablemente la prueba de demanda</p>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <hr>
# <div style="text-align: center">
#     <h2>Casos de fuentes malas</h2>
# </div>

# %% [markdown]
# <table>
#     <tr>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/horror_01.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">KOSMO KS 18M</figcaption>
#             </figure>
#             <strong>4.8A !!??</strong>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/Belsic.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center">Belsic<br/>Nótese el capacitor hinchado de entrada</figcaption>
#             </figure>
#         </td>
#         <td>
#             <figure style="text-align: center">
#                 <img src="images/horror_02.jpg" width=400px style="background: white"/>
#                 <figcaption style="text-align: center"></figcaption>
#             </figure>
#         </td>
#     </tr>
# </table>

# %%
import numpy as np
from math import exp,pow
from IPython.display import Math,Latex,Markdown
import matplotlib.pyplot as plt
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)

"""
## Prueba de corriente máxima y regulación
Utilizando una dummy-load de corriente constante (ajustable) en paralelo con una resistencia de entre 1.7 y 2.7 ohm <br/>
<i>En este tipo de pruba, es normal tener una tensión inferior a los 5V esperados</i> <br/>
"""

fig = plt.figure(figsize=(12,6))
ax1 = fig.add_subplot(1,1,1)

current = [1.7256, 1.7507, 1.8032, 1.8512, 1.9019, 1.9507, 2.0007, 2.0516, 2.1026, 2.1506, 2.2009, 2.2517, 2.3009, 2.3522, 2.4020]
voltage = [4.708,  4.700,  4.685,  4.670,  4.653,  4.638,  4.621,  4.607,  4.592,  4.581,  4.568,  4.551,  4.536,  4.524,  4.508]
ax1.plot(current, voltage, label="Pronext FU-5V2500")

current = [1.7085, 1.7508, 1.8014, 1.8504, 1.9023, 1.9504, 2.0030, 2.0513, 2.1016, 2.1530, 2.2000, 2.2525, 2.3022, 2.3519, 2.4024, 2.4504,
           2.5032, 2.5530, 2.6010, 2.6522, 2.7020, 2.7520, 2.8002, 2.8540, 2.9010, 2.9520, 3.0011, 3.0533, 3.1016]
voltage = [4.756,  4.742,  4.727,  4.712,  4.696,  4.681,  4.665,  4.650,  4.635,  4.618,  4.603,  4.587,  4.571,  4.555,  4.539,  4.523,
           4.507,  4.490,  4.473,  4.457,  4.441,  4.424,  4.408,  4.391,  4.376,  4.358,  4.342,  4.324, 4.307]
ax1.plot(current, voltage, label="Probattery FASW-053100F")

current = [1.7020, 1.7535, 1.8070, 1.8515, 1.9030, 1.9530, 2.0014, 2.0537, 2.1021, 2.1520, 2.2022, 2.2528, 2.3016, 2.3513, 2.4056, 2.4525,
           2.5030, 2.5555, 2.6040, 2.6515, 2.7029, 2.7505, 2.8040, 2.8508, 2.9015, 2.9515, 3.0025]
voltage = [4.525,  4.508,  4.491,  4.478,  4.461,  4.444,  4.427,  4.408,  4.389,  4.371,  4.353,  4.335,  4.318,  4.300,  4.278,  4.261,
           4.242,  4.228,  4.210,  4.195,  4.175,  4.157,  4.136,  4.116,  4.093,  4.068,  4.042]
ax1.plot(current, voltage, label="Motorola -TurboPower- SC-56")

current = [1.7005, 1.7515, 1.8015, 1.8511, 1.9018, 1.9526, 2.0025, 2.0525, 2.1040, 2.1517, 2.2012, 2.2511, 2.3037, 2.3516, 2.4018, 2.4537,
           2.5040, 2.5524, 2.6010, 2.6535, 2.7038, 2.7535, 2.8000, 2.8512, 2.9025, 2.9519, 3.0017, 3.0526, 3.1025, 3.1513, 3.2012, 3.2500,
           3.3047, 3.3525, 3.4044, 3.4512, 3.5037]
voltage = [4.481,  4.457,  4.434,  4.409,  4.385,  4.358,  4.330,  4.306,  4.278,  4.250,  4.222,  4.190,  4.166,  4.153,  4.132,  4.121,
           4.097,  4.073,  4.047,  4.019,  3.992,  3.965,  3.936,  3.906,  3.879,  3.853,  3.825,  3.810,  3.784,  3.758,  3.729,  3.720,
           3.688,  3.654,  3.617,  3.588,  3.561]
ax1.plot(current, voltage, label="DC/DC 5V5A \"XY-3606T\"")

current = [1.7024, 1.7519, 1.8012, 1.8559, 1.9031, 1.9532, 2.0038, 2.0499, 2.1010, 2.1503, 2.2020, 2.2524, 2.3031, 2.3521, 2.4064, 2.4478,
           2.5046, 2.5538, 2.6019, 2.6528, 2.7035, 2.7513, 2.8027, 2.8507, 2.9061, 2.9520, 3.0004]
voltage = [4.527,  4.508,  4.489,  4.467,  4.449,  4.430,  4.411,  4.391,  4.370,  4.350,  4.329,  4.309,  4.288,  4.266,  4.243,  4.227,
           4.204,  4.184,  4.164,  4.140,  4.118,  4.098,  4.077,  4.056,  4.031,  4.011,  3.989]
ax1.plot(current, voltage, label="DC/DC 5V3A \"HW-298\"")

current = [1.7008, 1.7509, 1.8033, 1.8519, 1.9003, 1.9511, 2.0011, 2.0516, 2.1018, 2.1527, 2.2043, 2.2513, 2.3008]
voltage = [4.398,  4.373,  4.349,  4.326,  4.304,  4.279,  4.255,  4.231,  4.207,  4.182,  4.157,  4.132,  4.108]
ax1.plot(current, voltage, label="DC/DC 5V MP2314")

current = [1.7077, 1.7509, 1.8021, 1.8504, 1.9023, 1.9527, 2.0007, 2.0539, 2.1025, 2.1519, 2.2019]
voltage = [4.535,  4.522,  4.468,  4.462,  4.417,  4.390,  4.334,  4.277,  4.230,  4.187,  4.147]
ax1.plot(current, voltage, label="DC/DC MP1584")

current = [1.7031, 1.7140, 1.7229, 1.7316, 1.7414, 1.7523, 1.7603, 1.7734, 1.7835, 1.7910, 1.8021, 1.8137, 1.8236, 1.8330, 1.8437, 1.8516, 1.8618, 1.8719, 1.8843, 1.8921,
           1.9009, 1.9114, 1.9209, 1.9305, 1.9422, 1.9511, 1.9606, 1.9714, 1.9826, 1.9925, 2.0016, 2.0106, 2.0209, 2.0308, 2.0414, 2.0511, 2.0599, 2.0705, 2.0818, 2.0933,
           2.1014, 2.1114, 2.1225, 2.1319, 2.1407, 2.1509, 2.1604, 2.1713, 2.1814, 2.1906, 2.2026, 2.2105, 2.2221, 2.2315, 2.2407, 2.2508, 2.2618, 2.2719, 2.2827, 2.2935,
           2.3039, 2.3156, 2.3251, 2.3307, 2.3416, 2.3516, 2.3643, 2.3705, 2.3809, 2.3907, 2.4030, 2.4109, 2.4223, 2.4307, 2.4414, 2.4501, 2.4616, 2.4713, 2.4804, 2.4906,
           2.5012, 2.5105, 2.5223, 2.5305, 2.5418, 2.5544, 2.5611, 2.5713, 2.5827, 2.5931, 2.6037, 2.6105, 2.6227, 2.6307, 2.6415, 2.6530, 2.6617, 2.6709, 2.6815, 2.6923, 2.7011]
voltage = [4.534,  4.513,  4.520,  4.519,  4.518,  4.509,  4.510,  4.505,  4.502,  4.501,  4.483,  4.493,  4.490,  4.486,  4.480,  4.459,  4.470,  4.458,  4.455,  4.452,
           4.428,  4.440,  4.434,  4.429,  4.423,  4.394,  4.415,  4.416,  4.402,  4.420,  4.389,  4.410,  4.402,  4.397,  4.390,  4.362,  4.378,  4.370,  4.364,  4.357,
           4.333,  4.345,  4.338,  4.343,  4.330,  4.284,  4.309,  4.295,  4.289,  4.273,  4.257,  4.272,  4.268,  4.259,  4.251,  4.234,  4.244,  4.236,  4.232,  4.223,
           4.207,  4.210,  4.203,  4.197,  4.188,  4.180,  4.169,  4.188,  4.184,  4.175,  4.165,  4.158,  4.119,  4.108,  4.105,  4.139,  4.101,  4.101,  4.079,  4.081,
           4.112,  4.113,  4.104,  4.100,  4.090,  4.083,  4.075,  4.059,  4.055,  4.068,  4.062,  4.055,  4.048,  4.045,  4.036,  4.029,  4.017,  4.011,  3.985,  3.996,  3.977]
ax1.plot(current, voltage, label="DC/DC LM2596HVS")

current = [1.7018, 1.7507, 1.8008, 1.8507, 1.9044, 1.9528, 2.0016, 2.0529, 2.1023, 2.1500, 2.2006, 2.2518, 2.3020, 2.3516, 2.4010, 2.4525, 2.5006, 2.5516, 2.6010, 2.6521]
voltage = [4.173,  4.147,  4.122,  4.097,  4.070,  4.045,  4.019,  3.993,  3.955,  3.932,  3.907,  3.883,  3.857,  3.832,  3.809,  3.782,  3.757,  3.729,  3.703,  3.680]
ax1.plot(current, voltage, label="ATX PSU")

ax1.set_title('Tensión de salida vs Corriente')
ax1.legend()
ax1.set_xlim(1.6, 3.2)
ax1.set_ylim(3.80, 4.80)
ax1.set_xlabel('Corriente (A)')
ax1.set_ylabel('Tensión (Vcc)')
ax1.xaxis.set_major_locator(MultipleLocator(0.1))
ax1.xaxis.set_minor_locator(AutoMinorLocator(5))
ax1.yaxis.set_major_locator(MultipleLocator(0.25))
ax1.yaxis.set_minor_locator(AutoMinorLocator(10))
ax1.grid(which='major', color='#CCCCCC', linestyle='--')
ax1.grid(which='minor', color='#CCCCCC', linestyle=':')

# %% [markdown]
# ## Links
#
# <ul>
# <li><a href="https://poweren.com/safety/can-a-mobile-phone-charger-be-dangerous/">Can a mobile phone charger be dangerous?</a></li>
# <li><a href="https://lygte-info.dk/info/SMPS%20workings%20UK.html">How does a usb charger work?</a></li>
# <li><a href="http://www.righto.com/2012/03/">Tiny, cheap, and dangerous: Inside a (fake) iPhone charger</a></li>
# <li><a href="https://www.ti.com/seclit/ml/slup227/slup227.pdf">Safety Considerations in Power Supply Design</a></li>
# <li><a href="https://www.epanorama.net/newepa/2013/10/08/safety-analysis-one-one-usb-power-supply/">Safety analysis of one USB power supply</a></li>
# <li><a href="https://studylib.net/doc/18109402/ul-840-insulation-coordination-including-clearances-and-c...">UL 840 Insulation Coordination Including Clearances and Creepage</a></li>
# </ul>
# <!-- https://www.youtube.com/watch?app=desktop&v=tWG0SNYzFRI -->
